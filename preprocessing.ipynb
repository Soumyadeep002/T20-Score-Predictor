# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
import pickle 
file = open("dataframe.pkl", 'rb')
final_df = pickle.load(file)

final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
#
#    meta.created  meta.revision    info.city    info.dates info.gender  \
# ...

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.by.wickets', 'info.outcome.winner', 'info.overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'match_id',
#        'info.outcome.by.runs', 'info.neutral_venue', 'info.outcome.method',
#        'info.outcome.result', 'info.outcome.eliminator',
#        'info.match_type_number', 'info.bowl_out', 'info.outcome.bowl_out',
#        'info.supersubs.New Zealand', 'info.supersubs.South Africa'],
#       dtype='object')

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
], inplace=True)

# %%
len(final_df.columns)
# Out:
# 14

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'], inplace=True)
len(final_df.columns)
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\2040785798.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'], inplace=True)
# 13

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs'], inplace=True)
len(final_df.columns)
# Out:
# 12

# %%
final_df
# Out:
#                                               innings    info.city  \
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...      Colombo
# 0   [{'1st innings': {'team': 'Australia', 'delive...          NaN
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...        Dubai
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...       Mirpur
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...       Mirpur
# ..                                                ...          ...
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...          NaN
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  Londonderry
# 0   [{'1st innings': {'team': 'Australia', 'delive...          NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...     Victoria
# 0   [{'1st innings': {'team': 'Australia', 'delive...          NaN
#
#       info.dates info.match_type info.outcome.winner info.player_of_match  \
# 0   [2016-09-09]             T20           Australia         [GJ Maxwell]
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in final_df.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []


    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    # delivery_df = delivery_df.append(loop_df)
    delivery_df = pd.concat([loop_df, delivery_df])

# %%
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0         964  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1         964  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2         964  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3         964  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4         964  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121         2  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122         2  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123         2  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124         2  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125         2  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team
        

delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0         964  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1         964  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2         964  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3         964  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4         964  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121         2  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122         2  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123         2  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124         2  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125         2  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'teams', 'batting_team', 'ball', 'batsman', 'bowler',
#        'runs', 'player_dismissed', 'city', 'venue', 'bowling_team'],
#       dtype='object')

# %%
delivery_df.drop(columns=['teams'],inplace=True)

delivery_df['batting_team'].unique()

teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0         964    Australia   0.1         AJ Finch  SL Malinga     0
# 1         964    Australia   0.2         AJ Finch  SL Malinga     0
# 2         964    Australia   0.3         AJ Finch  SL Malinga     1
# 3         964    Australia   0.4        M Klinger  SL Malinga     2
# 4         964    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121         2    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122         2    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123         2    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124         2    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125         2    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

df = output

# %% [markdown]
# ## **Feature Extraction**
#
# 1. batting_team
# 2. bowling_team
# 3. city
# 4. current score
# 5. ball left
# 6. wickets left
# 7. current run rate
# 8. score in last five overs

# %% [markdown]
# ## city

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8671
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
df['venue'].str.split().apply(lambda x:x[0])
# Out:
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
#          ...
# 121            R
# 122            R
# 123            R
# 124            R
# 125            R
# Name: venue, Length: 64241, dtype: object

# %%
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x:x[0]), df['city'])

# %%
df['city'] = cities
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\37896294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'] = cities

# %%
eligble_city = df['city'].value_counts()[df['city'].value_counts() > 600].index.to_list()

# %%
df = df[df['city'].isin(eligble_city)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                0
# 1         964    Australia    Sri Lanka   0.2     0                0
# 2         964    Australia    Sri Lanka   0.3     1                0
# 3         964    Australia    Sri Lanka   0.4     2                0
# 4         964    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121         2    Sri Lanka    Australia  19.3     1                0
# 122         2    Sri Lanka    Australia  19.4     0                0
# 123         2    Sri Lanka    Australia  19.5     0      DM de Silva
# 124         2    Sri Lanka    Australia  19.6     2                0
# 125         2    Sri Lanka    Australia  19.7     1                0
#
#           city                     venue
# 0    Melbourne  Melbourne Cricket Ground
# 1    Melbourne  Melbourne Cricket Ground
# ...

# %%
df.drop(columns=["venue"], inplace=True)
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\3807318888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["venue"], inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                0
# 1         964    Australia    Sri Lanka   0.2     0                0
# 2         964    Australia    Sri Lanka   0.3     1                0
# 3         964    Australia    Sri Lanka   0.4     2                0
# 4         964    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121         2    Sri Lanka    Australia  19.3     1                0
# 122         2    Sri Lanka    Australia  19.4     0                0
# 123         2    Sri Lanka    Australia  19.5     0      DM de Silva
# 124         2    Sri Lanka    Australia  19.6     2                0
# 125         2    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %% [markdown]
# ## Current Score

# %%
df["current_score"] = df.groupby("match_id")["runs"].cumsum()
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\4248034878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["current_score"] = df.groupby("match_id")["runs"].cumsum()

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                0
# 1         964    Australia    Sri Lanka   0.2     0                0
# 2         964    Australia    Sri Lanka   0.3     1                0
# 3         964    Australia    Sri Lanka   0.4     2                0
# 4         964    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121         2    Sri Lanka    Australia  19.3     1                0
# 122         2    Sri Lanka    Australia  19.4     0                0
# 123         2    Sri Lanka    Australia  19.5     0      DM de Silva
# 124         2    Sri Lanka    Australia  19.6     2                0
# 125         2    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# ...

# %% [markdown]
# ## Balls Left

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split('.')[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split('.')[1])                                 
df
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\3208575812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split('.')[0])
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\3208575812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split('.')[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df["balls_bowled"] = df['over'].astype('int')*6 + df['ball_no'].astype('int')
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\3302609802.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["balls_bowled"] = df['over'].astype('int')*6 + df['ball_no'].astype('int')

# %%
# in T20 total number of balls is 120

df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\2281178543.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\2281178543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                0
# 1         964    Australia    Sri Lanka   0.2     0                0
# 2         964    Australia    Sri Lanka   0.3     1                0
# 3         964    Australia    Sri Lanka   0.4     2                0
# 4         964    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121         2    Sri Lanka    Australia  19.3     1                0
# 122         2    Sri Lanka    Australia  19.4     0                0
# 123         2    Sri Lanka    Australia  19.5     0      DM de Silva
# 124         2    Sri Lanka    Australia  19.6     2                0
# 125         2    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# ...

# %% [markdown]
# ## Wickets Left

# %%
x = df['player_dismissed'].apply(lambda x:0 if x == "0" else 1)
x.value_counts()
# Out:
# player_dismissed
# 0    47940
# 1     2669
# Name: count, dtype: int64

# %%
df['player_dismissed'] = x.astype('int')
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\1907801048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = x.astype('int')

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                 0
# 1         964    Australia    Sri Lanka   0.2     0                 0
# 2         964    Australia    Sri Lanka   0.3     1                 0
# 3         964    Australia    Sri Lanka   0.4     2                 0
# 4         964    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121         2    Sri Lanka    Australia  19.3     1                 0
# 122         2    Sri Lanka    Australia  19.4     0                 0
# 123         2    Sri Lanka    Australia  19.5     0                 1
# 124         2    Sri Lanka    Australia  19.6     2                 0
# 125         2    Sri Lanka    Australia  19.7     1                 0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
df['cumsum'] = df.groupby('match_id')['player_dismissed'].cumsum()
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\87224865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cumsum'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df['wickets_left'] = 10 - df['cumsum']
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\195503761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['cumsum']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                 0
# 1         964    Australia    Sri Lanka   0.2     0                 0
# 2         964    Australia    Sri Lanka   0.3     1                 0
# 3         964    Australia    Sri Lanka   0.4     2                 0
# 4         964    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121         2    Sri Lanka    Australia  19.3     1                 0
# 122         2    Sri Lanka    Australia  19.4     0                 0
# 123         2    Sri Lanka    Australia  19.5     0                 1
# 124         2    Sri Lanka    Australia  19.6     2                 0
# 125         2    Sri Lanka    Australia  19.7     1                 0
#
#           city  current_score over ball_no  balls_bowled  balls_left  cumsum  \
# ...

# %%
df['wickets_left'].value_counts()
# Out:
# wickets_left
# 10    9641
# 9     9152
# 8     8184
# 7     7786
# 6     5950
# 5     4403
# 4     2509
# 3     1669
# 2      912
# 1      358
# 0       45
# Name: count, dtype: int64

# %% [markdown]
# ## Current Run Rate

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
df
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\1226876470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0         964    Australia    Sri Lanka   0.1     0                 0
# 1         964    Australia    Sri Lanka   0.2     0                 0
# 2         964    Australia    Sri Lanka   0.3     1                 0
# 3         964    Australia    Sri Lanka   0.4     2                 0
# 4         964    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# ...

# %% [markdown]
# ## Last Five over Score

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

df['last_five'] = last_five
# Out:
# C:\Users\soumyadeep\AppData\Local\Temp\ipykernel_9304\1266894021.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df['runs'].value_counts()
# Out:
# runs
# 1    21172
# 0    17486
# 4     5353
# 2     3855
# 6     2340
# 3      294
# 5       96
# 7       13
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['match_id', 'batting_team', 'bowling_team', 'ball', 'runs',
#        'player_dismissed', 'city', 'current_score', 'over', 'ball_no',
#        'balls_bowled', 'balls_left', 'cumsum', 'wickets_left', 'crr',
#        'last_five'],
#       dtype='object')

# %%
my_df = df.groupby('match_id')['runs'].sum().reset_index().merge(df, on="match_id")

# %%
my_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     128    Sri Lanka    Australia   0.1       0
# 1             2     128    Sri Lanka    Australia   0.2       1
# 2             2     128    Sri Lanka    Australia   0.3       4
# 3             2     128    Sri Lanka    Australia   0.4       1
# 4             2     128    Sri Lanka    Australia   0.5       1
# ...         ...     ...          ...          ...   ...     ...
# 50604       964     168    Australia    Sri Lanka  19.3       2
# 50605       964     168    Australia    Sri Lanka  19.4       1
# 50606       964     168    Australia    Sri Lanka  19.5       1
# 50607       964     168    Australia    Sri Lanka  19.6       2
# 50608       964     168    Australia    Sri Lanka  19.7       4
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0    Colombo              0    0       1             1
# ...

# %%
my_final_df = my_df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wickets_left', 'crr', 'last_five', 'runs_x']]

# %%
my_final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Sri Lanka    Australia    Colombo              0         119
# 1        Sri Lanka    Australia    Colombo              1         118
# 2        Sri Lanka    Australia    Colombo              5         117
# 3        Sri Lanka    Australia    Colombo              6         116
# 4        Sri Lanka    Australia    Colombo              7         115
# ...            ...          ...        ...            ...         ...
# 50604    Australia    Sri Lanka  Melbourne            160           3
# 50605    Australia    Sri Lanka  Melbourne            161           2
# 50606    Australia    Sri Lanka  Melbourne            162           1
# 50607    Australia    Sri Lanka  Melbourne            164           0
# 50608    Australia    Sri Lanka  Melbourne            168           0
#
#        wickets_left        crr  last_five  runs_x
# 0                10   0.000000        NaN     128
# ...

# %%
my_final_df.to_csv("T20_mens_dataset.csv", index=False)
